# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.optimizers import SGD, Adam

# %%
batch_size = 32
num_classes = 10
epochs = 12
mnist = keras.datasets.fashion_mnist
img_rows, img_cols = 28, 28

# %%
(X_train,y_train),(X_test,y_test) = mnist.load_data()

# %%
if K.image_data_format()=='channels_first':
  X_train = X_train.reshape(X_train.shape[0],1,img_rows,img_cols)
  X_test = X_test.reshape(X_test.shape[0],1,img_rows,img_cols)
  input_shape = (1,img_rows,img_cols)

else:
  X_train = X_train.reshape(X_train.shape[0],img_rows,img_cols,1)
  X_test = X_test.reshape(X_test.shape[0],img_rows,img_cols,1)
  input_shape = (img_rows,img_cols,1)

X_train = X_train/255.0
X_test = X_test/255.0

print("X_train shape:",X_train.shape)
print("y_train shape:",y_train.shape)
print("X_test shape:",X_test.shape)
print("y_test shape:",y_test.shape)
# Out:
# X_train shape: (60000, 28, 28, 1)
# y_train shape: (60000,)
# X_test shape: (10000, 28, 28, 1)
# y_test shape: (10000,)

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# y_train shape: (60000, 10)
# y_test shape: (10000, 10)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(100, activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.compile(loss=keras.losses.categorical_crossentropy,optimizer=Adam(),metrics=['accuracy'])

# %%
model.fit(X_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(X_test, y_test))
# Out:
# Epoch 1/12
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.8669 - loss: 0.3676 - val_accuracy: 0.8978 - val_loss: 0.2780
# Epoch 2/12
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9163 - loss: 0.2310 - val_accuracy: 0.9121 - val_loss: 0.2372
# Epoch 3/12
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9351 - loss: 0.1773 - val_accuracy: 0.9192 - val_loss: 0.2294
# Epoch 4/12
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9499 - loss: 0.1373 - val_accuracy: 0.9214 - val_loss: 0.2429
# Epoch 5/12
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9605 - loss: 0.1070 - val_accuracy: 0.9200 - val_loss: 0.2495
# Epoch 6/12
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9712 - loss: 0.0785 - val_accuracy: 0.9199 - val_loss: 0.2873
# Epoch 7/12
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9777 - loss: 0.0598 - val_accuracy: 0.9165 - val_loss: 0.3305
# Epoch 8/12
# ...

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.4697391986846924
# Test accuracy: 0.9212999939918518

# %%
model.save('mnist_cnn_model.keras')
print('Saved Successfully')
# Out:
# Saved Successfully

# %% [markdown]
# **PREDICTION**

# %%
from keras.preprocessing.image import load_img, img_to_array
from keras.models import load_model
import numpy as np

# Load the saved model (if not already loaded)
model = load_model('mnist_cnn_model.keras')

# Step 1: Load the image
# Replace the path with your grayscale (preferably 28x28) image in your directory, if it's not 28x28, load_img will resize it.
try:
    img = load_img('sample_pullover.png', color_mode='grayscale', target_size=(28, 28))
    print(f"Image loaded successfully: {img}")

except FileNotFoundError:
    print("Error: Image file not found. Please upload an image and update the path.")

except Exception as e:
    print(f"An error occurred: {e}")

# Step 2: Convert image to array
img_array = img_to_array(img)

# Step 3: Preprocess the image
# Reshape to (1, 28, 28, 1) for a single image, matching model input shape
img_array = img_array.reshape(1, 28, 28, 1)

# Normalize pixel values to 0-1
img_array = img_array / 255.0
print(f"Preprocessed image shape: {img_array.shape}")

# Step 4: Make the prediction
predictions_new_image = model.predict(img_array)

# Get the predicted class
predicted_class_new_image = predictions_new_image[0]
predicted_class_new_image = np.argmax(predictions_new_image[0])

print(f"\nPrediction for the loaded image:")
print(f"Predicted class: {predicted_class_new_image}")

if predicted_class_new_image ==0: print("This image is a T-shirt/Top")
elif predicted_class_new_image ==1: print("This image is a Trousers")
elif predicted_class_new_image ==2: print("This image is a Pullover")
elif predicted_class_new_image ==3: print("This image is a Dress")
elif predicted_class_new_image ==4: print("This image is a Coat")
elif predicted_class_new_image ==5: print("This image is a Sandal")
elif predicted_class_new_image ==6: print("This image is a Shirt")
elif predicted_class_new_image ==7: print("This image is a Sneaker")
elif predicted_class_new_image ==8: print("This image is a Bag")
elif predicted_class_new_image ==9: print("This image is a Ankleboot")
else: print("Error")
# Out:
# Image loaded successfully: <PIL.Image.Image image mode=L size=28x28 at 0x7D0122742540>
# Preprocessed image shape: (1, 28, 28, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
#
# Prediction for the loaded image:
# Predicted class: 2
# This image is a Pullover
